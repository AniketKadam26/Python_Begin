# %%
print("Hello World") #single line comment
# Out:
# Hello World

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# # python is a case sensitive language

# %% [raw]
# This is my first print statement
# Pythone is very interesting to learn

# %% [raw]
# above syntax for multiline syntax

# %%
x=10

# %%
x
# Out:
# 10

# %% [markdown]
# # rules for variable declaration

# %% [raw]
# 1.Variable name cannot start with numbers
# 2.we cannot start variable name except alphabets and _
# 3.Symbols can't be a part of variable name except _

# %%
my_name="Aniket"

# %%
my_name
# Out:
# 'Aniket'

# %%
_my_info="hello"

# %%
_my_info
# Out:
# 'hello'

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
b=30.90

# %%
type(b)
# Out:
# float

# %%
c="hello"

# %%
type(c)
# Out:
# str

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
t="Itvedant"

# %%
b="Pune"

# %%
t+b #concatenation
# Out:
# 'ItvedantPune'

# %%
t*2 #repetation
# Out:
# 'ItvedantItvedant'

# %%
t/b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 t/b
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
x=10
print("The value of x is ",x)
# Out:
# The value of x is  10

# %%
x=10
y=30
z=x+y
print("Addition of x and y is",z)
# Out:
# Addition of x and y is 40

# %%
a=20
b=10
c=a-b
print("Substraction of a and b is",c)
# Out:
# Substraction of a and b is 10

# %%
m=2
n=3
o=m*n
print("Multiplication of m and n is",o)
# Out:
# Multiplication of m and n is 6

# %%
p=10
q=5
r=p/q
print("Division of p and q is",r)
# Out:
# Division of p and q is 2.0

# %%
p=10
q=5
r=p%q
print("Modulous of p and q is",r)
# Out:
# Modulous of p and q is 0

# %%
p=10
q=5
r=p//q
print("Flor  Division of p and q is",r)
# Out:
# Flor  Division of p and q is 2

# %%
a=20
b=5
print("Addition of",a,"and",b,"is","=",a+b)
print("Substraction of",a,"and",b,"is","=",a-b)
print("Multiplication of",a,"and",b,"is","=",a*b)
print("Division of",a,"and",b,"is","=",a/b)
print("Modulous of",a,"and",b,"is","=",a%b)
print("Floor division of",a,"and",b,"is","=",a//b)
# Out:
# Addition of 20 and 5 is = 25
# Substraction of 20 and 5 is = 15
# Multiplication of 20 and 5 is = 100
# Division of 20 and 5 is = 4.0
# Modulous of 20 and 5 is = 0
# Floor division of 20 and 5 is = 4

# %%
a="Ram"
print("Good Morning ",a)
# Out:
# Good Morning  Ram

# %%
f_name="Aniket"
l_name="Kadam"
print("My first name is",f_name, "and My last name is",l_name)
# Out:
# My first name is Aniket and My last name is Kadam

# %% [raw]
# How to insert values from user

# %%
f_name=input("enter first name")
l_name=input("enter Last name")
print("my full name is",f_name,l_name)
# Out:
# enter first nameAniket
# enter Last nameKadam
# my full name is Aniket Kadam

# %%
type(f_name)
# Out:
# str

# %%
a=input("enter a number")
# Out:
# enter a number12

# %%
type(a)
# Out:
# str

# %% [raw]
# above code says type of a will be string bydefault because of input

# %% [markdown]
# # type Casting

# %%
b="2"
type(b)
# Out:
# str

# %%
c=int(b)

# %%
type(c)
# Out:
# int

# %%
a=23

# %%
type(a)
# Out:
# int

# %%
r=str(a)

# %%
type(r)
# Out:
# str

# %%
a
# Out:
# 23

# %%
r
# Out:
# '23'

# %%
x=1

# %%
x=bool(x)

# %%
x
# Out:
# True

# %%
a=int(input("enter a number"))
# Out:
# enter a number23

# %%
type(a)
# Out:
# int

# %%
r=float(input("radius is"))
pi=3.142
r_circle=pi*r*r
print("The area of circle is",r_circle)
# Out:
# radius is2.5
# The area of circle is 19.6375

# %%
l=int(input("length is"))
b=float(input("breadth is"))
rect=l*b
perimeter=2*(l+b)
print("The area of Rectangle is",rect)
print("the perimeter of rectangli is",perimeter)
# Out:
# length is2
# breadth is2.5
# The area of Rectangle is 5.0
# the perimeter of rectangli is 9.0

# %%
pi=3.142
r=int(input("enter radius of circle"))
l=int(input("enter length of rectangle"))
b=int(input("enter width of rectangle"))
s=int(input("enter side of square"))
print("***********************************************")
print("radius is",r)
print("length is",l)
print("width is",b)
print("side is",s)
print("***********************************************")
print("area of circle is",pi*r**2)
print("circumference of circle is  ",2*pi*r)
print("area of rectangle is ",l*b)
print("perimeter of rectangle is ",2*(l+b))
print("area of square is",s**2)
print("perimeter of square is ",4*s)
# Out:
# enter radius of circle4
# enter length of rectangle4
# enter width of rectangle6
# enter side of square4
# ***********************************************
# radius is 4
# length is 4
# width is 6
# side is 4
# ***********************************************
# area of circle is 50.272
# circumference of circle is   25.136
# area of rectangle is  24
# perimeter of rectangle is  20
# area of square is 16
# perimeter of square is  16

# %% [markdown]
# # indexing and slicing

# %%
s='ITVEDANT'

# %%
s[2]
# Out:
# 'V'

# %%
s[0]
# Out:
# 'I'

# %%
s[-1]
# Out:
# 'T'

# %%
len(s)
# Out:
# 8

# %%
s[-6]
# Out:
# 'V'

# %%
s

# %%
a="Aniket Kadam"
print(a[0])
print(a[6])
print(a[4])
print("length of given String is",len(a))
print(a[-4])
print("***** Slicing **********")
print(a[2:6])
print(a[-6::])
print(a[3::])
print(a[::2])
print(a[::-1])
print(a[-1:-8:-1])
# Out:
# A
#
# e
# length of given String is 12
# a
# ***** Slicing **********
# iket
#  Kadam
# ket Kadam
# Aie aa
# madaK tekinA
# madaK t

# %%
s="Hello! I am a student"
print("length of given string is",len(s))
print(s[-4::])
print(s[12:21])
print(s[5])
print(s[7:11])
print(s[14::][::-1])  #s[:-8:-1]
print(s[::-1])
# Out:
# length of given string is 21
# dent
# a student
# !
# I am
# tneduts
# tneduts a ma I !olleH

# %%
a1=s.replace("Hello","hi")

# %%
a1
# Out:
# 'hi! I am a student'

# %%
a2=s.replace("student","STUDENT")

# %%
a2
# Out:
# 'Hello! I am a STUDENT'

# %%
s.count("e")
# Out:
# 2

# %%
s.count("l")
# Out:
# 2

# %%
s.upper()
# Out:
# 'HELLO! I AM A STUDENT'

# %%
s.lower()
# Out:
# 'hello! i am a student'

# %%
s.capitalize()
# Out:
# 'Hello! i am a student'

# %%
s.find("a")
# Out:
# 9

# %%
s.endswith("student")
# Out:
# True

# %%
s.endswith("st")
# Out:
# False

# %%
a1=s.split(" ")

# %%
a1
# Out:
# ['Hello!', 'I', 'am', 'a', 'student']

# %%
l="hi hi hello! How are you?"
len(l)
l.count("hi")
l.count(" ")
l.count("i")
a1=l.replace("hi","hello")
l.endswith("you?")
a2=l.split("!")
a3=l.split("hi")
l.lower()
l.upper()
l.capitalize()
# Out:
# 'Hi hi hello! how are you?'

# %%
len(l)
# Out:
# 25

# %%
l.count("hi")
# Out:
# 2

# %%
l.count(" ")
# Out:
# 5

# %%
l.count("i")
# Out:
# 2

# %%
a1=l.replace("hi","hello")

# %%
a1
# Out:
# 'hello hello hello! How are you?'

# %%
l.endswith("you?")
# Out:
# True

# %%
a2=l.split("!")

# %%
a2
# Out:
# ['hi hi hello', ' How are you?']

# %%
a3=l.split("hi")

# %%
a3
# Out:
# ['', ' ', ' hello! How are you?']

# %%
l.lower()
# Out:
# 'hi hi hello! how are you?'

# %%
l.upper()
# Out:
# 'HI HI HELLO! HOW ARE YOU?'

# %%
l.capitalize()
# Out:
# 'Hi hi hello! how are you?'

# %%
s=str(input("Take one string from user"))
n=int(input("take one integer nuber from user"))
print(s)
print(n)
print(s*n)
s+"Good Morning"
# Out:
# Take one string from userhello guys..
# take one integer nuber from user2
# hello guys..
# 2
# hello guys..hello guys..
# 'hello guys..Good Morning'

# %% [markdown]
# # List

# %% [raw]
# list is one of the advance data type
# list is mutable or which we can change or manupulation(add, update,and delete)
# list is heterogeneous data type
# list is indexed== having index in nuber
# list is ordered==having fixead place

# %%
l="" #creating empty string

# %%
type(l)
# Out:
# str

# %%
l=[] #creating empty list

# %%
type(l)
# Out:
# list

# %%
k=[1,"hello",True,12.45]  #heterogeneous

# %%
type(k)
# Out:
# list

# %%
import PIL

# %%
from PIL import Image

# %%
t=Image.open("D:/vsm.jpg")

# %%
t
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=652x1313>

# %%
t1=t.rotate(90)

# %%
t1
# Out:
# <PIL.Image.Image image mode=RGB size=652x1313>

# %%
s=Image.open("D:\hruta12.jpg")

# %%
s
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1080>

# %%
t2=s.effect_spread(200000)

# %%
t2
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080>

# %%
p=[12,"hello",True,t,s]

# %%
p[0]
# Out:
# 12

# %%
p[1]
# Out:
# 'hello'

# %%
p[1][-1]
# Out:
# 'o'

# %%
l=[1,2,[3,4,["Hello",True],5],6]

# %%
l[2]
# Out:
# [3, 4, ['Hello', True, 5], 6]

# %%
l[2][2]
# Out:
# ['Hello', True, 5]

# %%
l[2][2][1]
# Out:
# True

# %%
l[3]
# Out:
# 6

# %%
l=[1,2,3,[6,7,8,9],10,11]

# %%
l[3][1:]
# Out:
# [7, 8, 9]

# %%
l[1]=20

# %%
print(l)
# Out:
# [1, 20, 3, [6, 7, 8, 9], 10, 11]

# %%
l[3]=30

# %%
l
# Out:
# [1, 20, 3, 30, 10, 11]

# %%
a=89
b=90

# %%
a,b=b,a

# %%
a
# Out:
# 90

# %%
b
# Out:
# 89

# %%
x=[1,"hi",56,89.90]

# %%
x.append("hello")

# %%
x
# Out:
# [1, 'hi', 56, 89.9, 'hello']

# %%
x.append(49)

# %%
x
# Out:
# [1, 'hi', 56, 89.9, 'hello', 49]

# %%
x.insert(1,30)

# %%
x
# Out:
# [1, 30, 'hi', 56, 89.9, 'hello', 49]

# %% [markdown]
# # update

# %%
x[3]="xyz"

# %%
x
# Out:
# [1, 30, 'hi', 'xyz', 89.9, 'hello', 49]

# %%
x[2]=90

# %%
x
# Out:
# [1, 30, 90, 'xyz', 89.9, 'hello', 49]

# %%
x[-6]="Aniket"

# %%
x
# Out:
# [1, 'Aniket', 90, 'xyz', 89.9, 'hello', 49]

# %% [markdown]
# # delete

# %%
x
# Out:
# [1, 'Aniket', 90, 'xyz', 89.9, 'hello', 49]

# %%
x.pop()  #last value deleted
# Out:
# 49

# %%
x
# Out:
# [1, 'Aniket', 90, 'xyz', 89.9, 'hello']

# %%
x.remove(90)

# %%
x
# Out:
# [1, 'Aniket', 'xyz', 89.9, 'hello']

# %%
x.remove("xyz")

# %%
x
# Out:
# [1, 'Aniket', 89.9, 'hello']

# %%
v=[12,10,89,56,34,90]

# %%
v.sort()

# %%
v
# Out:
# [10, 12, 34, 56, 89, 90]

# %%
v.sort(reverse=True)

# %%
v
# Out:
# [90, 89, 56, 34, 12, 10]

# %%
v[::-1]
# Out:
# [10, 12, 34, 56, 89, 90]

# %% [markdown]
# # Tuple

# %% [raw]
# tuple is immutable data type
# tuple defined by parenthesis ()
# tuple is indexed
# tuple is ordered

# %%
t=()  #empty tuple

# %%
type(t)
# Out:
# tuple

# %%
t=(6)

# %%
type(t)
# Out:
# int

# %%
t=(6,)

# %%
type(t)
# Out:
# tuple

# %%
r=20,23,34

# %%
type(r)
# Out:
# tuple

# %%
g=9,

# %%
type(g)
# Out:
# tuple

# %%
v=(23,"hi",78.98,23)

# %%
len(v)
# Out:
# 4

# %%
v.count(23)
# Out:
# 1

# %%
v
# Out:
# (23, 'hi', 78.98)

# %%
s=[32,"hello",32]

# %%
type(s)
# Out:
# list

# %%
s.count(32)
# Out:
# 2

# %% [raw]
# WAP to ask user to enter seven fruits name and stroe it into list

# %%
fruits=input("Enter seven fruits names").split(",")
print(fruits)
# Out:
# Enter seven fruits namesa b c d e f g
# ['a b c d e f g']

# %%
type(fruits)
# Out:
# list

# %%
names=input("enter 4 names").split(",")
# Out:
# enter 4 namesdivya,abhi,shekhar,dada

# %%
names.sort()

# %%
names
# Out:
# ['abhi', 'dada', 'divya', 'shekhar']

# %%
t=(0,3,4,5,0,0,5,0)

# %%
t.count(0)
# Out:
# 4

# %% [markdown]
# # Dictionary

# %% [raw]
# dictionary is key value pair
# dictionary defined by {}
# dictionary is unindexed
# dictionary is ordered
# mutable
# heterogeneous
# key should be unique

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d={"name":"Ram","marks":10}

# %%
d["name"]
# Out:
# 'Ram'

# %%
d["marks"]
# Out:
# 10

# %%
k={"name":["abc","pqr","xyz"],"marks":[10,20,30]}

# %%
k
# Out:
# {'name': ['abc', 'pqr', 'xyz'], 'marks': [10, 20, 30]}

# %%
k["name"]
# Out:
# ['abc', 'pqr', 'xyz']

# %%
k["marks"]
# Out:
# [10, 20, 30]

# %%
k.keys()
# Out:
# dict_keys(['name', 'marks'])

# %%
k.values()
# Out:
# dict_values([['abc', 'pqr', 'xyz'], [10, 20, 30]])

# %%
k.items()
# Out:
# dict_items([('name', ['abc', 'pqr', 'xyz']), ('marks', [10, 20, 30])])

# %%
k["age"]=[23,45,60]

# %%
k
# Out:
# {'name': ['abc', 'pqr', 'xyz'], 'marks': [10, 20, 30], 'age': [23, 45, 60]}

# %%
d={"names":["Rohini","Aniket","Vivek"],"age":[23,22,20]}

# %%
d.keys()
# Out:
# dict_keys(['names', 'age'])

# %%
d.values()
# Out:
# dict_values([['Rohini', 'Aniket', 'Vivek'], [23, 22, 20]])

# %% [markdown]
# d.items()

# %%
d.items()
# Out:
# dict_items([('names', ['Rohini', 'Aniket', 'Vivek']), ('age', [23, 22, 20])])

# %%
d["names"]
# Out:
# ['Rohini', 'Aniket', 'Vivek']

# %%
d["age"]
# Out:
# [23, 22, 20]

# %%
d["age"][2]
# Out:
# 20

# %%
d["age"].append(26)

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek'], 'age': [23, 22, 20, 26]}

# %%
d["names"].append("Anand")

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek', 'Anand'], 'age': [23, 22, 20, 26]}

# %%
d["address"]=["pune","mumbai","solapur","latur"]

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek', 'Anand'],
#  'age': [23, 22, 20, 26],
#  'address': ['pune', 'mumbai', 'solapur', 'latur']}

# %%
d["marks"]=[30,40,50,60]

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek', 'Anand'],
#  'age': [23, 22, 20, 26],
#  'address': ['pune', 'mumbai', 'solapur', 'latur'],
#  'marks': [30, 40, 50, 60]}

# %%
f={"course":["c1","c2","c3","c4"],"grade":["A","B","C","D"]}

# %%
f
# Out:
# {'course': ['c1', 'c2', 'c3', 'c4'], 'grade': ['A', 'B', 'C', 'D']}

# %% [markdown]
# # update in dictionary

# %%
d.update(f)

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek', 'Anand'],
#  'age': [23, 22, 20, 26],
#  'address': ['pune', 'mumbai', 'solapur', 'latur'],
#  'marks': [30, 40, 50, 60],
#  'course': ['c1', 'c2', 'c3', 'c4'],
#  'grade': ['A', 'B', 'C', 'D']}

# %% [markdown]
# # delete dictionary

# %%
d.pop("address")
# Out:
# ['pune', 'mumbai', 'solapur', 'latur']

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek', 'Anand'],
#  'age': [23, 22, 20, 26],
#  'marks': [30, 40, 50, 60],
#  'course': ['c1', 'c2', 'c3', 'c4'],
#  'grade': ['A', 'B', 'C', 'D']}

# %%
d["names"].remove("Anand")

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek'],
#  'age': [23, 22, 20, 26],
#  'marks': [30, 40, 50, 60],
#  'course': ['c1', 'c2', 'c3', 'c4'],
#  'grade': ['A', 'B', 'C', 'D']}

# %%
d["marks"].remove(50)

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek'],
#  'age': [23, 22, 20, 26],
#  'marks': [30, 40, 60],
#  'course': ['c1', 'c2', 'c3', 'c4'],
#  'grade': ['A', 'B', 'C', 'D']}

# %%
d["abc"]=[12,89,12,67,12]

# %%
d
# Out:
# {'names': ['Rohini', 'Aniket', 'Vivek'],
#  'age': [23, 22, 20, 26],
#  'marks': [30, 40, 60],
#  'course': ['c1', 'c2', 'c3', 'c4'],
#  'grade': ['A', 'B', 'C', 'D'],
#  'abc': [12, 89, 12, 67, 12]}

# %%
d["abc"].count(12)  #count in dictionary
# Out:
# 3

# %% [markdown]
# # delete dictionary

# %%
del d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# # Assignment

# %%
t={"product":["a","b","c"],"p_id":[12,13,14]}

# %%
t
# Out:
# {'product': ['a', 'b', 'c'], 'p_id': [12, 13, 14]}

# %%
t["product"].append("d")

# %%
t
# Out:
# {'product': ['a', 'b', 'c', 'd'], 'p_id': [12, 13, 14]}

# %%
t["product"].append("e")

# %%
t
# Out:
# {'product': ['a', 'b', 'c', 'd', 'e'], 'p_id': [12, 13, 14]}

# %%
t["p_id"].append(15)

# %%
t
# Out:
# {'product': ['a', 'b', 'c', 'd', 'e'], 'p_id': [12, 13, 14, 15]}

# %%
t["p_id"].append(16)

# %%
t
# Out:
# {'product': ['a', 'b', 'c', 'd', 'e'], 'p_id': [12, 13, 14, 15, 16]}

# %%
t["c_p"]=[10,20,30,40]

# %%
t
# Out:
# {'product': ['a', 'b', 'c', 'd', 'e'],
#  'p_id': [12, 13, 14, 15, 16],
#  'c_p': [10, 20, 30, 40]}

# %%
t["s_p"]=[30,25,12,45]

# %%
t
# Out:
# {'product': ['a', 'b', 'c', 'd', 'e'],
#  'p_id': [12, 13, 14, 15, 16],
#  'c_p': [10, 20, 30, 40],
#  's_p': [30, 25, 12, 45]}

# %%
t["profit"]=["c_p"-s_p]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 t["profit"]=[c_p-s_p]
#
# NameError: name 'c_p' is not defined

# %%
t["product"].remove("b")

# %%
t
# Out:
# {'product': ['a', 'c', 'd', 'e'],
#  'p_id': [12, 13, 14, 15, 16],
#  'c_p': [10, 20, 30, 40],
#  's_p': [30, 25, 12, 45]}

# %%
t["p_id"].remove(13)

# %%
t
# Out:
# {'product': ['a', 'c', 'd', 'e'],
#  'p_id': [12, 14, 15, 16],
#  'c_p': [10, 20, 30, 40],
#  's_p': [30, 25, 12, 45]}

# %%
t.pop("p_id")
# Out:
# [12, 14, 15, 16]

# %%
t
# Out:
# {'product': ['a', 'c', 'd', 'e'],
#  'c_p': [10, 20, 30, 40],
#  's_p': [30, 25, 12, 45]}

# %%
t.values()
# Out:
# dict_values([['a', 'c', 'd', 'e'], [10, 20, 30, 40], [30, 25, 12, 45]])

# %%
t.keys()
# Out:
# dict_keys(['product', 'c_p', 's_p'])

# %%
t.items()
# Out:
# dict_items([('product', ['a', 'c', 'd', 'e']), ('c_p', [10, 20, 30, 40]), ('s_p', [30, 25, 12, 45])])

# %%
t["product"][1]="w"

# %%
t
# Out:
# {'product': ['a', 'w', 'd', 'e'],
#  'c_p': [10, 20, 30, 40],
#  's_p': [30, 25, 12, 45]}

# %%
t["c_p"][0]=20

# %%
t
# Out:
# {'product': ['a', 'w', 'd', 'e'],
#  'c_p': [20, 20, 30, 40],
#  's_p': [30, 25, 12, 45]}

# %%
del t

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 t
#
# NameError: name 't' is not defined

# %% [markdown]
# # set

# %% [raw]
# set {}
# duplicate are not allowed
# unindexed
# unordered
# there is no way to change elements inside sets.
# only we can add elements in a set

# %%
s=set() #empty set

# %%
type(s)
# Out:
# set

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
d={12,34,12,34,56}

# %%
d
# Out:
# {12, 34, 56}

# %%
f={1,1,2,3,3,4}

# %%
len(f)  #bcz in set duplicates are not allowed
# Out:
# 4

# %%
f
# Out:
# {1, 2, 3, 4}

# %%
f.pop()
# Out:
# 1

# %%
f.pop()
# Out:
# 2

# %%
f
# Out:
# {3, 4}

# %%
f.add(5)

# %%
f.add(6)

# %%
f
# Out:
# {3, 4, 5, 6}

# %%
s1={1,2,3,4}

# %%
s2={1,2,5,6}

# %%
s1-s2
# Out:
# {3, 4}

# %%
s2-s1
# Out:
# {5, 6}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %%
{1,2,3}=={1,1,2,3}
# Out:
# True

# %%
{4,5,6}=={1,2,3}
# Out:
# False

# %%
s=set()
s.add(12)
s.add(12.0)
s.add("12")

# %%
len(s)
# Out:
# 2

# %%
s=set()
s.add(12)
s.add(12.1)
s.add("12")

# %%
len(s)
# Out:
# 3

# %%
s={12,34,[12,34],(12,34)}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 s={12,34,[12,34],(12,34)}
#
# TypeError: unhashable type: 'list'

# %%
s={12,34,{12,34}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 s={12,34,{12,34}}
#
# TypeError: unhashable type: 'set'

# %% [raw]
# WAP 8numbers from user and display unique numbers

# %%
number=(input("enter 8 numbers fro user")).split(",")
s=set(number)
# Out:
# enter 8 numbers fro user1,1,2,3,2,4,5,6

# %%
s
# Out:
# {'1', '2', '3', '4', '5', '6'}

# %%
type(s)
# Out:
# set

# %%
a=["a","b","c"]
a1=[1,2,3]

# %%
list(zip(a,a1))
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
dict(zip(a,a1))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
